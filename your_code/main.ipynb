# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
import pandas as pd
import numpy as np

from IPython.display import display

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
employee = pd.read_csv('data/Employee.csv')

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
display(pd.pivot_table(data = employee, index = 'Department', values = 'Salary', aggfunc = np.mean))
display(employee.groupby('Department').agg({'Salary':np.mean}))
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
pd.pivot_table(data = employee, index = 'Department', columns = 'Title', values = 'Salary', aggfunc = np.mean)
# Out:
# Title         VP  analyst  associate
# Department
# HR          70.0     32.5        NaN
# IT          70.0     32.5       60.0
# Sales        NaN      NaN       55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
pd.pivot_table(data = employee, index = 'Title', columns = 'Years', values = 'Salary', aggfunc = np.mean)
# Out:
# Years         1     2     3     4     7     8
# Title
# VP          NaN   NaN   NaN   NaN   NaN  70.0
# analyst    35.0  30.0   NaN  35.0   NaN   NaN
# associate   NaN  55.0  55.0   NaN  60.0   NaN

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
pd.pivot_table(data = employee, index = 'Department', columns = 'Title', values = 'Salary', aggfunc = [np.mean, len])
# Out:
#             mean                    len
# Title         VP analyst associate   VP analyst associate
# Department
# HR          70.0    32.5       NaN  1.0     2.0       NaN
# IT          70.0    32.5      60.0  1.0     2.0       1.0
# Sales        NaN     NaN      55.0  NaN     NaN       2.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
pd.pivot_table(data = employee, index = 'Department', columns = 'Title', values = 'Salary', aggfunc = [np.median, np.min, np.max, np.std])
# Out:
#            median                    amin                    amax          \
# Title          VP analyst associate    VP analyst associate    VP analyst
# Department
# HR           70.0    32.5       NaN  70.0    30.0       NaN  70.0    35.0
# IT           70.0    32.5      60.0  70.0    30.0      60.0  70.0    35.0
# Sales         NaN     NaN      55.0   NaN     NaN      55.0   NaN     NaN
#
#                            std
# Title      associate   analyst associate
# Department
# HR               NaN  3.535534       NaN
# IT              60.0  3.535534       NaN
# Sales           55.0       NaN       0.0

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
employee.isna().sum() # No missing values in the employee table.
# Out:
# Name          0
# Department    0
# Education     0
# Gender        0
# Title         0
# Years         0
# Salary        0
# dtype: int64

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
pd.pivot_table(data = employee, index = 'Department', 
               values = 'Salary', aggfunc = [len, np.sum])
# Out:
#               len    sum
#            Salary Salary
# Department
# HR              3    135
# IT              4    195
# Sales           2    110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
display('Sum of years per department and title')
display(pd.pivot_table(data = employee, index = 'Department', columns = 'Title', values = 'Years', aggfunc = np.sum))
display('Mean salary per department and title')
display(pd.pivot_table(data = employee, index = 'Department', columns = 'Title', values = 'Salary', aggfunc = np.mean))
display(pd.pivot_table(data = employee, index = 'Department', columns = 'Title', values = ['Salary', 'Years'], aggfunc = [np.mean, np.sum]))
# Out:
# 'Sum of years per department and title'
# Title        VP  analyst  associate
# Department
# HR          8.0      6.0        NaN
# IT          8.0      3.0        7.0
# Sales       NaN      NaN        5.0
# 'Mean salary per department and title'
# Title         VP  analyst  associate
# Department
# HR          70.0     32.5        NaN
# IT          70.0     32.5       60.0
# Sales        NaN      NaN       55.0
#              mean                                              sum          \
#            Salary                   Years                   Salary
# Title          VP analyst associate    VP analyst associate     VP analyst
# Department
# HR           70.0    32.5       NaN   8.0     3.0       NaN   70.0    65.0
# IT           70.0    32.5      60.0   8.0     1.5       7.0   70.0    65.0
# Sales         NaN     NaN      55.0   NaN     NaN       2.5    NaN     NaN
#
#
#                      Years
# Title      associate    VP analyst associate
# Department
# ...
